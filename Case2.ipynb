# %% [markdown]
# ## Problem 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
url = ("https://raw.githubusercontent.com/holleland/TECH3/refs/heads/main/data/ekstrom2025.csv")
data = pd.read_csv(url, sep = ";")

# %%
data.head()
# Out:
#    id              date      treatment  reported_diceroll  correct_guess  age  \
# 0   1  07.05.2019 16:04  Trust_promise                  1              0   37
# 1   2  07.05.2019 09:37        Control                  2              0   53
# 2   3  07.05.2019 09:37  Trust_promise                  6              0   29
# 3   4  07.05.2019 09:38  Trust_promise                  1              0   20
# 4   5  07.05.2019 09:38        Control                  2              0   66
#
#    female  education  universitydegree  sector  employed  highincome  \
# 0       0          3                 1       1         1         NaN
# 1       0          4                 1       1         1         1.0
# 2       0          4                 1       1         1         1.0
# 3       1          2                 0       3         0         0.0
# 4       1          2                 0       1         1         0.0
#
#    politicalright  believeingod  believeinfreewill  generaltrust
# ...

# %%
#1. possible values of x=(1 to 6)
#Probability distribution of x, P(X=x)=1/6 for x=1,2,3,4,5,6
# they are uniformally distributed

# %% [markdown]
# ## Problem 4

# %%
n=len(data.index)
print(data['reported_diceroll'].value_counts().sort_index()/n)
sns.countplot(x='reported_diceroll', data=data, stat='probability')
plt.axhline(y=1/6, color='r', linestyle='--')
plt.show()
# Out:
# reported_diceroll
# 1    0.14875
# 2    0.17000
# 3    0.17250
# 4    0.17375
# 5    0.16875
# 6    0.16625
# Name: count, dtype: float64

# %%
sns.countplot(x='correct_guess', data=data, stat='probability')
plt.axhline(y=1/6, color='r', linestyle='--')
plt.show()
